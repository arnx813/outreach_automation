# %%
import pandas as pd
df = pd.read_csv("result.csv")

# basic data cleanse
df = df[df['name'].str.split().str.len() <= 2]
pattern = r'.+at Fortress'
df = df[df['job'].str.contains(pattern, regex=True, na=False)]

# get emails
df['email'] = df['name'].str.extract(r'(\w)\w*\s(\w+)', expand=False).apply('.'.join, axis=1)
df['email'] = df['email'] + "@fortress.com"

# create new csv
df.to_csv('df.csv', index=False)

df
# Out:
#                                             profileUrl             name  \
# 2                   https://www.linkedin.com/in/joeyxu        Joanna Xu
# 3    https://www.linkedin.com/in/nick-chapman-0348a947     Nick Chapman
# 5    https://www.linkedin.com/in/kurt-rodrigues-0ba...   Kurt Rodrigues
# 7                https://www.linkedin.com/in/clairemxu        Claire Xu
# 9    https://www.linkedin.com/in/branton-foo-b88a0b121      Branton Foo
# ..                                                 ...              ...
# 600  https://www.linkedin.com/in/scott-jorgensen-74...  Scott Jorgensen
# 605  https://www.linkedin.com/in/chelsea-carges-9b5...   Chelsea Carges
# 622    https://www.linkedin.com/in/avi-dreyfuss-baa653     Avi Dreyfuss
# 627  https://www.linkedin.com/in/justin-gilman-6924...    Justin Gilman
# 629  https://www.linkedin.com/in/steven-willemin-64...  Steven Willemin
#
#     firstName   lastName                                                job  \
# 2      Joanna         Xu  Real Estate Investing at Fortress Investment G...
# 3        Nick    Chapman             Associate at Fortress Investment Group
# 5        Kurt  Rodrigues               Analyst at Fortress Investment Group
# 7      Claire         Xu             Associate at Fortress Investment Group
# 9     Branton        Foo             Associate at Fortress Investment Group
# ..        ...        ...                                                ...
# 600     Scott  Jorgensen        Vice President at Fortress Investment Group
# 605   Chelsea     Carges  Senior Vice President, Corporate Operations an...
# 622       Avi   Dreyfuss  CFO in the Credit Division at Fortress Investm...
# 627    Justin     Gilman  Vice President, Controller at Fortress Investm...
# 629    Steven   Willemin              Director at Fortress Investment Group
#
#                             location  connectionDegree  \
# 2             San Francisco Bay Area               2.0
# 3    New York City Metropolitan Area               2.0
# 5                       New York, NY               2.0
# 7                       New York, NY               3.0
# 9                                NaN               2.0
# ..                               ...               ...
# 600  New York City Metropolitan Area               3.0
# 605  New York City Metropolitan Area               3.0
# 622                   Cedarhurst, NY               3.0
# 627                       Dallas, TX               3.0
# 629                     New York, NY               3.0
#
#                                                  query  \
# 2    https://www.linkedin.com/company/fortress-inve...
# 3    https://www.linkedin.com/company/fortress-inve...
# 5    https://www.linkedin.com/company/fortress-inve...
# 7    https://www.linkedin.com/company/fortress-inve...
# 9    https://www.linkedin.com/company/fortress-inve...
# ..                                                 ...
# 600  https://www.linkedin.com/company/fortress-inve...
# 605  https://www.linkedin.com/company/fortress-inve...
# 622  https://www.linkedin.com/company/fortress-inve...
# 627  https://www.linkedin.com/company/fortress-inve...
# 629  https://www.linkedin.com/company/fortress-inve...
#
#                     timestamp error otherJob                     email
# 2    2023-02-02T16:34:54.444Z   NaN      NaN         J.Xu@fortress.com
# 3    2023-02-02T16:34:54.444Z   NaN      NaN    N.Chapman@fortress.com
# 5    2023-02-02T16:34:54.445Z   NaN      NaN  K.Rodrigues@fortress.com
# 7    2023-02-02T16:34:54.445Z   NaN      NaN         C.Xu@fortress.com
# 9    2023-02-02T16:34:54.445Z   NaN      NaN        B.Foo@fortress.com
# ..                        ...   ...      ...                       ...
# 600  2023-02-02T16:44:15.887Z   NaN      NaN  S.Jorgensen@fortress.com
# 605  2023-02-02T16:44:15.887Z   NaN      NaN     C.Carges@fortress.com
# 622  2023-02-02T16:44:34.143Z   NaN      NaN   A.Dreyfuss@fortress.com
# 627  2023-02-02T16:44:34.143Z   NaN      NaN     J.Gilman@fortress.com
# 629  2023-02-02T16:44:34.143Z   NaN      NaN   S.Willemin@fortress.com
#
# [310 rows x 12 columns]
